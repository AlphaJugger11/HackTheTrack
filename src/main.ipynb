# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../dataset/barber/03_Provisional Results_Race 1_Anonymized.CSV',sep=";")
df
# Out:
#     POSITION  NUMBER      STATUS  LAPS TOTAL_TIME  GAP_FIRST GAP_PREVIOUS  \
# 0          1      13  Classified    27  45:15.035          -            -
# 1          2      22  Classified    27  45:17.775     +2.740       +2.740
# 2          3      72  Classified    27  45:25.690    +10.655       +7.915
# 3          4      55  Classified    27  45:26.144    +11.109       +0.454
# 4          5       2  Classified    27  45:29.124    +14.089       +2.980
# 5          6      47  Classified    27  45:29.433    +14.398       +0.309
# 6          7      98  Classified    27  45:30.123    +15.088       +0.690
# 7          8       7  Classified    27  45:36.780    +21.745       +6.657
# 8          9      41  Classified    27  45:36.902    +21.867       +0.122
# 9         10     113  Classified    27  45:50.756    +35.721      +13.854
# 10        11      21  Classified    27  45:51.568    +36.533       +0.812
# 11        12     111  Classified    27  45:51.893    +36.858       +0.325
# ...

# %%
# Out:
# Index(['POSITION', 'NUMBER', 'STATUS', 'LAPS', 'TOTAL_TIME', 'GAP_FIRST',
#        'GAP_PREVIOUS', 'FL_LAPNUM', 'FL_TIME', 'FL_KPH', 'CLASS', 'GROUP',
#        'DIVISION', 'VEHICLE', 'TIRES', 'ECM Participant Id', 'ECM Team Id',
#        'ECM Category Id', 'ECM Car Id', 'ECM Brand Id', 'ECM Country Id',
#        '*Extra 7', '*Extra 8', '*Extra 9', 'Sort Key', 'DRIVER_*Extra 3',
#        'DRIVER_*Extra 4', 'DRIVER_*Extra 5'],
#       dtype='object')
